# %% [markdown]
# # Classification of Agricultural Pests using different ML models

# %%
from PIL import Image
import numpy as np
import pandas as pd
import csv
import os
from skimage.feature import graycomatrix, graycoprops

# %%
inputDirectory = "/kaggle/input/agricultural-pests-image-dataset/"

# %%
with open("/kaggle/working/features.csv", 'a', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Image','red_sum', 'green_sum', 'blue_sum', 'correlation', 'energy', 'contrast', 'homogeneity','label'])

# %%
def analyze_image(image_path):
    # Load the image
    image = Image.open(image_path)
    # Convert the image to RGB mode (if it's not already)
    image = image.convert("RGB")
    # Convert the image to a numpy array
    image_array = np.array(image)

    # Calculate the sums of colors on each channel
    red_sum = np.sum(image_array[:, :, 0])
    green_sum = np.sum(image_array[:, :, 1])
    blue_sum = np.sum(image_array[:, :, 2])

    # Convert the image to grayscale
    grayscale_image = image.convert("L")
    # Convert the grayscale image to a numpy array
    grayscale_array = np.array(grayscale_image)

    # Calculate the texture properties using greycomatrix and greycoprops
    glcm = graycomatrix(grayscale_array, distances=[1], angles=[0], symmetric=True, normed=True)
    correlation = graycoprops(glcm, 'correlation')[0, 0]
    energy = graycoprops(glcm, 'energy')[0, 0]
    contrast = graycoprops(glcm, 'contrast')[0, 0]
    homogeneity = graycoprops(glcm, 'homogeneity')[0, 0]

    # Return the calculated features as a list
    features = [image_array, red_sum, green_sum, blue_sum, correlation, energy, contrast, homogeneity]
    return features

# %%
for folder in os.listdir(inputDirectory):
    print("Inside folder {}".format(folder))
    folderPath = os.path.join(inputDirectory, folder)
    for img in os.listdir(folderPath):
        imgPath = os.path.join(folderPath, img)
        features = analyze_image(imgPath)
        features.append(folder)
        with open("/kaggle/working/features.csv", 'a', newline='') as file:
            writer = csv.writer(file)
            writer.writerow(features)
        print("Processed Image: {}".format(imgPath))
# Out:
# Inside folder beetle
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (219).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (285).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (124).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (342).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (320).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (186).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (145).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (88).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (355).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (171).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (203).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (33).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (24).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (184).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (302).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (60).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (110).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (121).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (250).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (264).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (237).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (253).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (354).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (313).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (83).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (298).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (192).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (366).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (314).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (324).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (57).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (98).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (132).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (68).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (140).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (114).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (236).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (131).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (37).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (232).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (210).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (11).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (287).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (111).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (79).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (329).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (23).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (65).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (211).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (6).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (82).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (307).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (410).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (204).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (308).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (290).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (299).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (368).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (414).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (168).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (258).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (364).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (398).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (338).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (381).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (405).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (420).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (138).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (279).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (126).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (81).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (249).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (117).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (174).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (389).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (418).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (181).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (2).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (28).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (283).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (166).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (346).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (183).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (328).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (263).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (330).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (134).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (322).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (127).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (189).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (75).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (144).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (22).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (194).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (318).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (265).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (106).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (409).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (296).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (257).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (235).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (252).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (412).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (146).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (335).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (36).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (207).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (91).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (205).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (353).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (163).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (180).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (48).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (102).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (176).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (58).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (116).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (229).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (419).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (18).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (216).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (94).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (238).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (16).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (272).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (100).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (1).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (55).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (169).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (234).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (413).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (21).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (222).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (87).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (386).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (218).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (350).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (196).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (53).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (19).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (269).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (275).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (187).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (50).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (49).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (51).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (103).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (43).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (165).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (38).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (32).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (223).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (201).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (112).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (339).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (213).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (67).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (130).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (317).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (325).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (380).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (13).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (417).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (123).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (293).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (74).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (159).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (301).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (262).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (31).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (384).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (85).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (56).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (274).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (104).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (115).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (93).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (373).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (30).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (244).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (245).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (292).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (217).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (388).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (193).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (288).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (306).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (321).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (200).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (101).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (185).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (191).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (177).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (96).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (141).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (226).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (41).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (270).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (407).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (170).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (332).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (136).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle (190).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/beetle/beetle
jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (84).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (264).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (83).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (58).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (244).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (143).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (340).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (291).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (328).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (313).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (233).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (239).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (111).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (343).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (383).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (102).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (188).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (7).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (173).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (336).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (370).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (118).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (16).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (305).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (381).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (23).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (325).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (314).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (29).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (26).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (355).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (379).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (35).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (219).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (21).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (77).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (279).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (140).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (298).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (153).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (59).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (90).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (5).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (366).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (194).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (301).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (260).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (312).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (108).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (290).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (280).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (240).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (255).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (161).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (80).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (261).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (309).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (319).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (205).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (346).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (207).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (253).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (75).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (87).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (377).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (247).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (288).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (178).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (117).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (104).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (127).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (28).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (72).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (367).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (299).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (71).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (335).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (48).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (385).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (229).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (231).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (382).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (322).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (82).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (256).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (275).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (225).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (257).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (45).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (378).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (138).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (341).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (304).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (120).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (208).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (139).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (144).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (52).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (217).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (330).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (271).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (259).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (164).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (214).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (323).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (175).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (121).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (20).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (348).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (110).jpg
# Processed Image: /kaggle/input/agricultural-pests-image-dataset/slug/slug (11).jpg

# %% [markdown]
# ## Load the data to a csv file and perform data standardization

# %%
df = pd.read_csv("/kaggle/working/features.csv")

# %%
df.head()
# Out:
#                                                Image   red_sum  green_sum  \
# 0  [[[119 124 128]\n  [116 121 124]\n  [137 138 1...   8541019    8546918
# 1  [[[240 249 255]\n  [240 249 255]\n  [240 249 2...  13530466   13407083
# 2  [[[237 237 235]\n  [237 237 235]\n  [237 237 2...  12309764   11363292
# 3  [[[ 23  44   1]\n  [ 23  44   1]\n  [ 23  44  ...   5571475    7941488
# 4  [[[141 178  98]\n  [142 179  99]\n  [143 180 1...   5733322    7479809
#
#    blue_sum  correlation    energy    contrast  homogeneity   label
# 0   8231608     0.906282  0.012002  323.347946     0.087765  beetle
# 1  13381422     0.950554  0.191100  142.611037     0.546303  beetle
# 2  10872450     0.965044  0.063243  212.055403     0.496337  beetle
# 3   2867010     0.986970  0.043663   45.376496     0.486561  beetle
# 4   2718236     0.971701  0.032272  107.877303     0.451339  beetle

# %%
df = df.drop(columns = ['Image'])

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
xTrain, xTest, yTrain, yTest = train_test_split(df.drop(columns=['label']), df['label'], train_size=0.8, random_state=42)

# %%
labelEncoder = LabelEncoder()
labelEncoder.fit(yTrain)
print(labelEncoder.classes_)
yTrain = labelEncoder.transform(yTrain)
yTest = labelEncoder.transform(yTest)
# Out:
# ['ants' 'bees' 'beetle' 'catterpillar' 'earthworms' 'earwig' 'grasshopper'
#  'moth' 'slug' 'snail' 'wasp' 'weevil']

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaler.fit(xTrain)
xTrain = scaler.transform(xTrain)
xTest = scaler.transform(xTest)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, matthews_corrcoef, cohen_kappa_score

# %%
with open("/kaggle/working/metrics.csv", 'a', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Model','Accuracy','Precision','Senstivity','F1 Score','MCC Score','Kappa Coeff'])

# %% [markdown]
# ### Support Vector Machine

# %%
from sklearn.svm import SVC

# %%
modelSVC = SVC()

# %%
modelSVC.fit(xTrain, yTrain)
# Out:
# SVC()

# %%
yPred = modelSVC.predict(xTest)

# %%
accuracy = accuracy_score(yTest, yPred)
precision = precision_score(yTest, yPred, average='micro')
senstivity = recall_score(yTest, yPred, average='micro')
f1 = f1_score(yTest, yPred, average='micro')
mcc = matthews_corrcoef(yTest, yPred)
kappa = cohen_kappa_score(yTest, yPred)

# %%
with open("/kaggle/working/metrics.csv", 'a', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['SVM',accuracy,precision,senstivity,f1,mcc,kappa])

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
modelDecisionTree = DecisionTreeClassifier()
modelDecisionTree.fit(xTrain, yTrain)
yPred = modelDecisionTree.predict(xTest)
accuracy = accuracy_score(yTest, yPred)
precision = precision_score(yTest, yPred, average='micro')
senstivity = recall_score(yTest, yPred, average='micro')
f1 = f1_score(yTest, yPred, average='micro')
mcc = matthews_corrcoef(yTest, yPred)
kappa = cohen_kappa_score(yTest, yPred)
with open("/kaggle/working/metrics.csv", 'a', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Decision Tree',accuracy,precision,senstivity,f1,mcc,kappa])

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
modelLogisticRegression = LogisticRegression()
modelLogisticRegression.fit(xTrain, yTrain)
yPred = modelLogisticRegression.predict(xTest)
accuracy = accuracy_score(yTest, yPred)
precision = precision_score(yTest, yPred, average='micro')
senstivity = recall_score(yTest, yPred, average='micro')
f1 = f1_score(yTest, yPred, average='micro')
mcc = matthews_corrcoef(yTest, yPred)
kappa = cohen_kappa_score(yTest, yPred)
with open("/kaggle/working/metrics.csv", 'a', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Logistic Regression',accuracy,precision,senstivity,f1,mcc,kappa])

# %% [markdown]
# ### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
modelRandomForestClassifier = RandomForestClassifier()
modelRandomForestClassifier.fit(xTrain, yTrain)
yPred = modelRandomForestClassifier.predict(xTest)
accuracy = accuracy_score(yTest, yPred)
precision = precision_score(yTest, yPred, average='micro')
senstivity = recall_score(yTest, yPred, average='micro')
f1 = f1_score(yTest, yPred, average='micro')
mcc = matthews_corrcoef(yTest, yPred)
kappa = cohen_kappa_score(yTest, yPred)
with open("/kaggle/working/metrics.csv", 'a', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Random Forest',accuracy,precision,senstivity,f1,mcc,kappa])

# %% [markdown]
# ### XGBClassifier

# %%
from xgboost import XGBClassifier
modelXGBClassifier = XGBClassifier()
modelXGBClassifier.fit(xTrain, yTrain)
yPred = modelXGBClassifier.predict(xTest)
accuracy = accuracy_score(yTest, yPred)
precision = precision_score(yTest, yPred, average='micro')
senstivity = recall_score(yTest, yPred, average='micro')
f1 = f1_score(yTest, yPred, average='micro')
mcc = matthews_corrcoef(yTest, yPred)
kappa = cohen_kappa_score(yTest, yPred)
with open("/kaggle/working/metrics.csv", 'a', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['XGBoost',accuracy,precision,senstivity,f1,mcc,kappa])

# %% [markdown]
# ### KNN Model

# %%
from sklearn.neighbors import KNeighborsClassifier
modelKNeighborsClassifier = KNeighborsClassifier()
modelKNeighborsClassifier.fit(xTrain, yTrain)
yPred = modelKNeighborsClassifier.predict(xTest)
accuracy = accuracy_score(yTest, yPred)
precision = precision_score(yTest, yPred, average='micro')
senstivity = recall_score(yTest, yPred, average='micro')
f1 = f1_score(yTest, yPred, average='micro')
mcc = matthews_corrcoef(yTest, yPred)
kappa = cohen_kappa_score(yTest, yPred)
with open("/kaggle/working/metrics.csv", 'a', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['KNN',accuracy,precision,senstivity,f1,mcc,kappa])

# %% [markdown]
# ## Model Accuracy

# %%
result = pd.read_csv("/kaggle/working/metrics.csv")

# %%
result
# Out:
#                  Model  Accuracy  Precision  Senstivity  F1 Score  MCC Score  \
# 0                  SVM  0.220200   0.220200    0.220200  0.220200   0.148648
# 1        Decision Tree  0.124659   0.124659    0.124659  0.124659   0.043905
# 2  Logistic Regression  0.192903   0.192903    0.192903  0.192903   0.119376
# 3        Random Forest  0.207461   0.207461    0.207461  0.207461   0.134454
# 4              XGBoost  0.207461   0.207461    0.207461  0.207461   0.134474
# 5                  KNN  0.182894   0.182894    0.182894  0.182894   0.109594
#
#    Kappa Coeff
# 0     0.145967
# 1     0.043898
# 2     0.116423
# 3     0.133955
# 4     0.134120
# 5     0.107940
